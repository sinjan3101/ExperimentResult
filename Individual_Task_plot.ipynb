# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data from Excel
df = pd.read_excel('TaskThresholdComparison.xlsx')

# Rename columns for clarity
'''df.columns = [
    'Force Intensity',
    'Pushing at a fixed point',
    'Pushing alongwith rolling over the surface',
    'Pushing along the edges'
]
tasks = [
    'Pushing at a fixed point',
    'Pushing alongwith rolling over the surface',
    'Pushing along the edges'
]
'''

df.columns = [
    'Force Intensity',
    'Pushing at a fixed point',
    'Pushing alongwith rolling over the surface',
    'Pushing along the edges'
]

'''
df.columns = [
    'Force Intensity',
    'Pushing alongwith rolling over the surface'
]
df.columns = [
    'Force Intensity',
    'Pushing along the edges'
]
'''

# Define plotting parameters
force_levels = df['Force Intensity']
tasks = [
    'Pushing at a fixed point'
]

'''
tasks = [
    'Pushing at a fixed point'
]

tasks = [
    'Pushing alongwith rolling over the surface'
]

tasks = [
    'Pushing along the edges'
]

tasks = [
    'Pushing at a fixed point',
    'Pushing alongwith rolling over the surface',
    'Pushing along the edges'
]
'''
colors = ['#3db6e3', '#f7c59f', '#c7e9b0']
figname = tasks[0]
plt.figure(figsize=(10, 5))
for i, task in enumerate(tasks):
    plt.plot(force_levels, df[task], marker='o', label=task, color=colors[i])
    #plt.xlabel('Force Intensity', fontsize=22)
    #plt.ylabel('Refresh Rate (Hz)', fontsize=22)
    #plt.grid(True, alpha=0.3)
    #plt.xticks(fontsize=22, rotation=15)
    #plt.yticks(fontsize=22)
    #plt.tight_layout()
    #plt.show()

plt.xlabel('Force Intensity', fontsize=22)
plt.ylabel('Refresh Rate (Hz)', fontsize=22)
#plt.title('Refresh Rate by Force Intensity', fontsize=17)
#plt.legend(title='Task', fontsize=21, title_fontsize=22)
plt.grid(True, alpha=0.1)
plt.xticks(fontsize=22, rotation=15)
plt.yticks(range(0, 1100, 100), fontsize=22)
plt.tight_layout()
plt.savefig(figname)
plt.show()
